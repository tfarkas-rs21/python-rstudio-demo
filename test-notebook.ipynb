# %%
import io
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
zillow_train = pd.read_csv("~/mothr-ds-python-templates/data/train.csv")

# %%
fig, ax = plt.subplots()
sns.relplot(data = zillow_train, y = "LotFrontage", x = "LotArea")
plt.show()
